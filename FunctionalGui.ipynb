# %%
from PyQt5 import QtCore, QtGui, QtWidgets
from PyQt5.QtCore import QObject, pyqtSlot
from test import Ui_MainWindow
import sys
from djitellopy.tello import Tello
import socket
import threading
import pywifi
import time
wifi = pywifi.PyWiFi()
# iface1 = wifi.interfaces()[0]
# iface2 = wifi.interfaces()[1]


from psutil import process_iter
from signal import SIGTERM # or SIGKILL

for proc in process_iter():
    for conns in proc.connections(kind='inet'):
        if conns.laddr.port == 9010:
            proc.send_signal(SIGTERM)

for proc in process_iter():
    for conns in proc.connections(kind='inet'):
        if conns.laddr.port == 9011:
            proc.send_signal(SIGTERM)            


# tello1 = Tello('192.168.10.2')
# tello1.connect()
# tello2 = Tello('192.168.10.3')
# tello2.connect()

# IP and port of Tello
tello1_address = ('192.168.0.10', 8889)
tello2_address = ('192.168.0.9', 8889)

# IP and port of local computer
local1_address = ('', 9010)
local2_address = ('', 9011)

sock1 = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
sock2 = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)

# Bind to the local address and port
sock1.bind(local1_address)
sock2.bind(local2_address)

def send(message ,delay):
  # Try to send the message otherwise print the exception
  try:
    sock1.sendto(message.encode(), tello1_address)
    sock2.sendto(message.encode(), tello2_address)
    print("Sending message: " + message)
    print("Sending message: " + message)
  except Exception as e:
    print("Error sending: " + str(e))

  # Delay for a user-defined period of time
  time.sleep(delay)

# Receive the message from Tello
def receive():
  # Continuously loop and listen for incoming messages
  while True:
    # Try to receive the message otherwise print the exception
    try:
      response1, ip_address = sock1.recvfrom(128)
      response2, ip_address = sock2.recvfrom(128)
      print("Received message: from Tello EDU #1: " + response1.decode(encoding='utf-8'))
      print("Received message: from Tello EDU #2: " + response2.decode(encoding='utf-8'))
    except Exception as e:
      # If there's an error close the socket and break out of the loop
      sock1.close()
      sock2.close()
      print("Error receiving: " + str(e))
      break

# Create and start a listening thread that runs in the background
# This utilizes our receive functions and will continuously monitor for incoming messages
receiveThread = threading.Thread(target=receive)
receiveThread.daemon = True
receiveThread.start()

    

class MainWindowUIClass( Ui_MainWindow ):
    def __init__( self ):
        '''Initialize the super class
        '''
        super().__init__()

global tello1
global tello2

def drone1():
    send("command",3)
#     for i in iface1.scan_results():
#         if i.ssid == "TELLO-56CF93":
#             iface1.connect(i)
#             time.sleep(5)
#             if iface1.status() == 4:
#                 print("drone1 is connected")
#     sock1.bind(('192.168.10.2',0))                
# #     global tello1 
# #     tello1 = Tello('192.168.10.2')
# #     tello1.connect()
#     msg="command"
#     msg = msg.encode(encoding="utf-8")
#     sent = sock1.sendto(msg,('192.168.10.1',8889))

def drone2():
    send("command",3)
#     for i in iface2.scan_results():
#         if i.ssid == "TELLO-56CEA3":
#             iface2.connect(i)
#             time.sleep(5)
#             if iface2.status() == 4:
#                 print("drone2 is connected")            
    
#     sock2.bind(('192.168.10.3',0))
# #     global tello2 
# #     tello2 = Tello('192.168.10.3')
# #     tello2.connect()
#     msg="command"
#     msg = msg.encode(encoding="utf-8")
#     sent = sock2.sendto(msg,('192.168.10.1',8889))

    
def takeoff():
#     bat1 = tello1.get_battery()
#     bat2 = tello2.get_battery()
#     bat1 = bat1.strip()
#     bat2 = bat2.strip()
#     if not int(bat1)>20 and int(bat2)>20:
#     tello1.takeoff()
#     tello2.takeoff()
#     msg="takeoff"
#     msg=msg.encode(encoding="utf-8")
#     sent = sock1.sendto(msg,('192.168.10.1',8889))
#     sent = sock2.sendto(msg,('192.168.10.1',8889))
    send("takeoff",3)
    print("taking off")
        
def land():
#     tello1.land()
#     tello2.land()

#     msg="land"
#     msg=msg.encode(encoding="utf-8")
#     sent = sock1.sendto(msg,('192.168.10.1',8889))
#     sent = sock2.sendto(msg,('192.168.10.1',8889))
    send("land",3)
    print("landing")
def right():
    send("flip r",3)
#     bat1 = tello1.get_battery()
#     bat2 = tello2.get_battery()
#     bat1 = bat1.strip()
#     bat2 = bat2.strip()
    
#     if not int(bat1)>20 and int(bat2)>20:
#     counter = 0
#     while not tello1.move_right(50):
#         if counter>=5:
#             tello1.land()
#             tello2.land()
#             print("malfunctioned!...landing now")
#             break
#         counter = counter+1
#         print("command failed")
        
#     counter = 0
#     while not tello2.move_right(50):
#         if counter>=5:
#             tello1.land()
#             tello2.land()
#             print("malfunctioned!...landing now")
#             break
#         counter = counter + 1
#         print("command failed")
#     print("moving right")
#     else:
#         print("battery low!, landing")
#         tello1.land()
#         tello2.land()        
#     tello1.send_command_with_return("right 100")
#     tello2.send_command_with_return("right 100")
    
def left():
    send("left 40",3)
#     bat1 = tello1.get_battery()
#     bat2 = tello2.get_battery()
#     bat1 = bat1.strip()
#     bat2 = bat2.strip()
    
#     if not int(bat1)>20 and int(bat2)>20:
#     counter = 0
#     while not tello1.move_left(50):
#         if counter>=5:
#             tello1.land()
#             tello2.land()
#             print("malfunctioned!...landing now")
#             break 
#         counter = counter +1
#         print("command failed")
#     counter = 0
#     while not tello2.move_left(50):
#         if counter>=5:
#             tello1.land()
#             tello2.land()
#             print("malfunctioned!...landing now")
#             break
#         counter = counter +1    
#         print("command failed")
#     print("moving left")
#     else:
#         print("battery low!, landing")
#         tello1.land()
#         tello2.land()
#     tello1.send_command_with_return("left 50")
#     tello2.send_command_with_return("left 50")
    
def forward():
    send("forward 40",3)
#     bat1 = tello1.get_battery()
#     bat2 = tello2.get_battery()
#     bat1 = bat1.strip()
#     bat2 = bat2.strip()
    
#     if not int(bat1)>20 and int(bat2)>20:
#     counter = 0
#     while not tello1.move_forward(50):
#         if counter>=5:
#             tello1.land()
#             tello2.land()
#             print("malfunctioned!...landing now")
#             break
#         counter = counter +1 
#         print("command failed")
#     counter = 0
#     while not tello2.move_forward(50):
#         if counter>=5:
#             tello1.land()
#             tello2.land()
#             print("malfunctioned!...landing now")
#             break
#         counter = counter +1
#         print("command failed")
#     print("moving forward")
#     else:
#         print("battery low!, landing")
#         tello1.land()
#         tello2.land()
#     tello1.send_command_with_return("forward 50")
#     tello2.send_command_with_return("forward 50")
    
def back():
    send("back 40",3)
#     bat1 = tello1.get_battery()
#     bat2 = tello2.get_battery()
#     bat1 = bat1.strip()
#     bat2 = bat2.strip()
    
#     if not int(bat1)>20 and int(bat2)>20:
#     counter = 0
#     while not tello1.move_back(50):
#         if counter>=5:
#             tello1.land()
#             tello2.land()
#             print("malfunctioned!...landing now")
#             break
#         counter = counter +1 
#         print("command failed")
#     counter = 0
#     while not tello2.move_back(50):
#         if counter>=5:
#             tello1.land()
#             tello2.land()
#             print("malfunctioned!...landing now")
#             break
#         counter = counter + 1
#         print("command failed")
#     print("moving back")
#     else:
#         print("battery low!, landing")
#         tello1.land()
#         tello2.land()
#     tello1.send_command_with_return("back 50")
#     tello2.send_command_with_return("back 50")
    
def down():
    send("down 40",3)
#     bat1 = tello1.get_battery()
#     bat2 = tello2.get_battery()
#     bat1 = bat1.strip()
#     bat2 = bat2.strip()
    
#     if not int(bat1)>20 and int(bat2)>20:
#     counter = 0
#     while not tello1.move_down(50):
#         if counter>=5:
#             tello1.land()
#             tello2.land()
#             print("malfunctioned!...landing now")
#             break
#         counter = counter + 1
#         print("command failed")
#     counter = 0
#     while not tello2.move_down(50):
#         if counter>=5:
#             tello1.land()
#             tello2.land()
#             print("malfunctioned!...landing now")
#             break
#         counter = counter+1
#         print("command failed")
#     print("moving down")
#     else:
#         print("battery low!, landing")
#         tello1.land()
#         tello2.land()        
#     tello1.send_command_with_return("down 50")
#     tello2.send_command_with_return("down 50")
    
def up():
    send("up 40",3)
#     bat1 = tello1.get_battery()
#     bat2 = tello2.get_battery()
#     bat1 = bat1.strip()
#     bat2 = bat2.strip()
    
#     if not int(bat1)>20 and int(bat2)>20:
#     counter = 0
#     while not tello1.move_up(50):
#         if counter>=5:
#             tello1.land()
#             tello2.land()
#             print("malfunctioned!...landing now")
#             break
#         counter = counter +1
#         print("command failed")
#     counter = 0
#     while not tello2.move_up(50):
#         if counter>=5:
#             tello1.land()
#             tello2.land()
#             print("malfunctioned!...landing now")
#             break
#         counter = counter +1
#         print("command failed")
#     print("moving up")
#     else:
#         print("battery low!, landing")
#         tello1.land()
#         tello2.land()
#     tello1.send_command_with_return("up 50")
#     tello2.send_command_with_return("up 50")
    
    
        
def main():
    """
    This is the MAIN ENTRY POINT of our application.  The code at the end
    of the mainwindow.py script will not be executed, since this script is now
    our main program.   We have simply copied the code from mainwindow.py here
    since it was automatically generated by '''pyuic5'''.

    """
    app = QtWidgets.QApplication(sys.argv)
    MainWindow = QtWidgets.QMainWindow()
    ui = MainWindowUIClass()
    ui.setupUi(MainWindow)
    ui.takeoffbtn.clicked.connect(takeoff)
    ui.landbtn.clicked.connect(land)
    ui.upbtn.clicked.connect(up)
    ui.backbtn.clicked.connect(back)
    ui.downbtn.clicked.connect(down)
    ui.forwardbtn.clicked.connect(forward)
    ui.leftbtn.clicked.connect(left)
    ui.rightbtn.clicked.connect(right)
    ui.drone1.clicked.connect(drone1)
    ui.drone2.clicked.connect(drone2)
    
    MainWindow.show()
    sys.exit(app.exec_())
# import threading
# import socket
# import sys
# import time

# sock1 = socket.socket(socket.AF_INET,socket.SOCK_DGRAM)

# sock2 = socket.socket(socket.AF_INET,socket.SOCK_DGRAM)

# def recv1():
#     while True:
#         try:
#             data,server = sock1.recvfrom(1518)
#             print(data.decode(encoding="utf-8"))
#         except Exception:
#             print('\nExit...\n')
#             break
                
# def recv2():
#     while True:
#         try:
#             data,server = sock2.recvfrom(1518)
#             print(data.decode(encoding="utf-8"))
#         except Exception:
#             print('\nExit...\n')
#             break            
# recv1Thread = threading.Thread(target=recv1)
# recv1Thread.start()
# recv2Thread = threading.Thread(target=recv2)
# recv2Thread.start()
main()
# Out:
# Sending message: command
# Sending message: command
# Received message: from Tello EDU #1: ok
# Received message: from Tello EDU #2: ok
# Sending message: takeoff
# Sending message: takeoff
# taking off
# Sending message: up 40
# Sending message: up 40
# Received message: from Tello EDU #1: ok
# Received message: from Tello EDU #2: error Not joystick
# Received message: from Tello EDU #1: ok
# Received message: from Tello EDU #2: ok
# Sending message: up 40
# Sending message: up 40
# Received message: from Tello EDU #1: ok
# Received message: from Tello EDU #2: ok
# Sending message: flip r
# Sending message: flip r
# Received message: from Tello EDU #1: ok
# Received message: from Tello EDU #2: ok
# Sending message: left 40
# Sending message: left 40
# Received message: from Tello EDU #1: ok
# Received message: from Tello EDU #2: ok
# Sending message: left 40
# Sending message: left 40
# Received message: from Tello EDU #1: ok
# Received message: from Tello EDU #2: ok
# ...
